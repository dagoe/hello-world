# %% [markdown]
# <a href="https://colab.research.google.com/github/dagoe/hello-world/blob/master/LightsDimmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ipywidgets import AppLayout, Button, Layout, GridspecLayout
from ipywidgets import Button, Layout, jslink, IntText, IntSlider

def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))

def create_colored_button(desc, col):
  b = Button(description=desc, layout=Layout(width='auto',height='80px'))
  b.style.button_color = col 
  return b

grid = GridspecLayout(5, 5)

for i in range(5):
    for j in range(5):
        grid[i, j] = create_colored_button(' {} - {}'.format(i, j), 'lightgreen')
grid
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d98307660865> in <module>
# ----> 1 from ipywidgets import AppLayout, Button, Layout, GridspecLayout
#       2 from ipywidgets import Button, Layout, jslink, IntText, IntSlider
#       3
#       4 def create_expanded_button(description, button_style):
#       5     return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))
#
# ImportError: cannot import name 'AppLayout' from 'ipywidgets' (/var/mobile/Containers/Data/Application/7145B8F0-F7E5-4C0D-9835-7B84D77F8D7A/Library/lib/python3.7/site-packages/ipywidgets/__init__.py)
